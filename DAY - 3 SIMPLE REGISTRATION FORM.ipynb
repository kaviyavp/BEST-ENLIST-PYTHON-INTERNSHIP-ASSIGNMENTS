# %%
#importing tkinter module for GUI application
from tkinter import *
import tkinter.messagebox

#Creating object 'root' of Tk()
root =Tk()

#Providing title to the form
root.title("Registration Form")

#Providing Geometry to the form
root.geometry('700x400')

#Providing Background color to the form
root.configure(background = "light green")

#this creates 'Label' widget for Registration Form 
label1=Label(root ,text= "REGISTRATION FORM",bg="light green",font=("bold", 20)).grid(row =0, column=2)

#this creates 'Label' widget for First Name 
Firstname = Label(root ,text = "First Name",bg="light green",width=20,font=("bold", 10)).grid(row = 1,column = 1)

#this creates 'Label' widget for Last Name
LastName = Label(root ,text = "Last Name",bg="light green",width=20,font=("bold", 10)).grid(row = 2,column = 1)

#this creates 'Label' widget for Address
Address = Label(root,text = "Address",bg="light green",width=20,font=("bold", 10)).grid(row = 3,column = 1)

#this creates 'Label' widget for City
City = Label(root ,text = "City",bg="light green",width=20,font=("bold", 10)).grid(row = 4,column = 1)

#this creates 'Label' widget for State
State= Label(root,text = "State",bg="light green",width=20,font=("bold", 10)).grid(row = 5,column = 1)

#this creates 'Label' widget for Country
Country = Label(root ,text = "Country",bg="light green",width=20,font=("bold", 10)).grid(row = 7,column = 1)

#this creates 'Label' widget for Postal /Zip Code
postal = Label(root,text = "Postal Code",bg="light green",width=20,font=("bold", 10)).grid(row = 6,column = 1)

#this creates list of countries available in the dropdownlist.
list1 = ['Canada','India','UK','US','Germany','Australia','Iceland','China'];

#the variable 'c' mentioned here holds String Value, by default ""
c=StringVar()
droplist=OptionMenu(root,c, *list1)
droplist.config(width=15)
c.set(' Select your Country')
droplist.grid(row = 7,column = 2)


#this creates 'Label' widget for Contact Number
Mobile = Label(root ,text = "Contact Number",bg="light green",width=20,font=("bold", 10)).grid(row = 8,column = 1)

#this creates 'Label' widget for Email Id
Email = Label(root ,text = "Email Id",bg="light green",width=20,font=("bold", 10)).grid(row = 9,column = 1)

#this creates 'Label' widget for Gender
Gender =Label(root ,text = "Gender",bg="light green",width=20,font=("bold", 10)).grid(row = 10,column = 1)

#the variable 'var' mentioned here holds Integer Value, by deault 0
var = IntVar()

#this creates 'Radio button' widget 
Radiobutton(root, text="Male",bg="light green",padx = 30, variable=var, value=1).grid(row = 10,column = 2)
Radiobutton(root, text="Female",bg="light green",padx = 20, variable=var, value=2).grid(row = 10,column = 3)

#this creates 'Label' widget for Date Of Birth
Choose =Label(root ,text = "Date Of Birth",bg="light green",width=20,font=("bold", 10)).grid(row = 11,column = 1)

Firstname1 = Entry(root).grid(row = 1,column = 2)
Lastna = Entry(root).grid(row = 2,column = 2)
Adderss1=Entry(root).grid(row = 3,column = 2)
city1=Entry(root).grid(row = 4,column = 2)
state1=Entry(root).grid(row = 5,column = 2)
postal1=Entry(root).grid(row = 6,column = 2)
Email1 = Entry(root).grid(row = 9,column = 2)
Mobile1 = Entry(root).grid(row = 8,column = 2)
choose1 = Entry(root).grid(row = 11,column = 2)


def onClick():
    tkinter.messagebox.showinfo("Registered", "Your Details Submitted  Successfully !")


# Create a Button
Button(root, text="Submit", command=onClick,width=20,bg='brown',fg='white').grid(row = 14,column = 2)


root.mainloop()
